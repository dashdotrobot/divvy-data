# %% [markdown]
# # Divvy station map

# %%
# %matplotlib inline
import smopy
import sodapy

data_url = 'data.cityofchicago.org'
divvy_data = 'fg6s-gzvg'

# %%
map_chi = smopy.Map((41.7, -87.800, 42.040, -87.55), z=10)

x, y = map_chi.to_pixels(42.020243, -87.673226)

ax = map_chi.show_mpl(figsize=(8, 12))
ax.plot(x, y, 'or', ms=10)
